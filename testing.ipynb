# %%
import pandas as pd

# %%
pd.read_csv("financial_data/AAPL.csv")
# Out:
#             Price                Close                 High  \
# 0          Ticker                 AAPL                 AAPL
# 1            Date                  NaN                  NaN
# 2      1980-12-12   0.0982070341706276  0.09863399757979115
# 3      1980-12-15  0.09308347851037979  0.09351044176057746
# 4      1980-12-16   0.0862513855099678  0.08667834324398599
# ...           ...                  ...                  ...
# 11447  2026-05-13    298.8699951171875    300.9200134277344
# 11448  2026-05-14    298.2099914550781   300.45001220703125
# 11449  2026-05-15    300.2300109863281   303.20001220703125
# 11450  2026-05-18    297.8399963378906    300.6600036621094
# 11451  2026-05-19    298.9700012207031     300.510009765625
#
#                        Low                 Open     Volume
# 0                     AAPL                 AAPL       AAPL
# 1                      NaN                  NaN        NaN
# 2       0.0982070341706276   0.0982070341706276  469033600
# ...
